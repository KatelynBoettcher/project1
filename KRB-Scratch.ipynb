# %%
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline
a = numpy.loadtxt('samples/1.raw', skiprows=1, delimiter=',')

# %%
plt.plot(a[:,0], a[:,1]);
len(a)
#plotting data stored in a variable
# Out:
# 80

# %%
# want to find the slope over the beginning linear region
# E = (delta Y)/(delta X)

# %%
a = numpy.loadtxt('samples/2.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 120

# %%
b = numpy.loadtxt('samples/3.raw', skiprows=1, delimiter=',')
plt.plot(b[:,0], b[:,1]);
len(b)
# Out:
# 100

# %%
#I want to get the slopes of initial linear sections
    #Find initial linear parts (differing numbers of points!)
    #Use stuff from notebook 4 (3?) to get linear regression of initial section
    
#I want to average slopes over all of the samples

# %%
a = numpy.loadtxt('samples/0.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 80

# %%
a = numpy.loadtxt('samples/4.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 100

# %%
a = numpy.loadtxt('samples/5.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 100

# %%
a = numpy.loadtxt('samples/6.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 80

# %%
a = numpy.loadtxt('samples/7.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 100

# %%
a = numpy.loadtxt('samples/8.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 120

# %%
a = numpy.loadtxt('samples/9.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 100

# %%
a = numpy.loadtxt('samples/10.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 80

# %%
#Observations:
    #80: very steep initial section, wiggly part alternates between jagged and more rounded areas
    #100: generally less steep than 80, has more wiggles and those are more jagged than round
    #120: only one so I can not make accurate observation

# %%
a = numpy.loadtxt('samples/11.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 120

# %%
a = numpy.loadtxt('samples/12.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 100

# %%
a = numpy.loadtxt('samples/13.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 100

# %%
a = numpy.loadtxt('samples/14.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 100

# %%
a = numpy.loadtxt('samples/15.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 100

# %%
a = numpy.loadtxt('samples/16.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 80

# %%
a = numpy.loadtxt('samples/17.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 80

# %%
a = numpy.loadtxt('samples/18.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 120

# %%
a = numpy.loadtxt('samples/19.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 80

# %%
a = numpy.loadtxt('samples/20.raw', skiprows=1, delimiter=',')
plt.plot(a[:,0], a[:,1]);
len(a)
# Out:
# 80

# %%
#Observations:
    #80 (8): slopes can either be extremely steep (2E5/0.02) or be more like 2E5/0.1
        #wiggles are generally more seperated compared to 100 and 120
    #100 (9): slopes also vary but tend to be less steep than 80 and with less variation
        #wiggles generally all have slight incline, have less seperation and rounds compared to 80
        #wiggles vary in peak heights
    #120 (4): slopes are generally at the same steepness
        #wiggles have greater incline compared to 10
        #wiggles vary in peak heights

# %%
#Next Two Steps:
    #Get linear regression for some of the data in a plot
        #do not care if it is right yet, just want a slope
    #Write code for selecting how much of plot to get linear regression (first section)
        #elastic deformation section, need right slopes for these

# %%
# Out:
#   File "<ipython-input-8-515826847d78>", line 5
#     plt.plot(a[:,0], a[:,1])
#       ^
# SyntaxError: invalid syntax

# %%
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = numpy.loadtxt('samples/0.raw', skiprows=1, delimiter=',')
stop = 5
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 5772496.467330081
# 80

# %%
a = numpy.loadtxt('samples/3.raw', skiprows=1, delimiter=',')
stop = 7
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 6400794.808129405
# 100

# %%
a = numpy.loadtxt('samples/2.raw', skiprows=1, delimiter=',')
stop = 13
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 4203839.03764619
# 120

# %%
#Observations:
    #I have only plotted 1 per different set of points and have not checked accuracy yet
    #80 use stop=5
    #100 use stop=7
    #120 use stop=13

# %%
a = numpy.loadtxt('samples/1.raw', skiprows=1, delimiter=',')
stop = 12
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 2363219.051257956
# 80

# %%
#Observation:
    #In 1, there are 80 points so I tried stop=5
        #technically works, but linear region bends slightly and keeps going
    #Stop=12 worked better to get it all the way to first technical wiggle

# %%
a = numpy.loadtxt('samples/6.raw', skiprows=1, delimiter=',')
stop = 8
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 4110805.095454434
# 80

# %%
a = numpy.loadtxt('samples/10.raw', skiprows=1, delimiter=',')
stop = 9
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 3345891.6998358774
# 80

# %%
a = numpy.loadtxt('samples/16.raw', skiprows=1, delimiter=',')
stop = 7
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 3681080.1326829535
# 80

# %%
a = numpy.loadtxt('samples/17.raw', skiprows=1, delimiter=',')
stop = 14
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 2614485.440786109
# 80

# %%
#Observation:
    #Similar to 1, stop=8 goes up until bend
    #stop=14 goes up until first wiggle

# %%
a = numpy.loadtxt('samples/19.raw', skiprows=1, delimiter=',')
stop = 10
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 3180695.6077827862
# 80

# %%
a = numpy.loadtxt('samples/20.raw', skiprows=1, delimiter=',')
stop = 9
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 3412350.576043236
# 80

# %%
#Observations:
    #Similar to 1 and 17, stop=5 works for first section
    #stop=9 goes up until first wiggle
    
#Stop=5, 12, 8, 9, 7, 14, 10, 9

# %%
def mean(num):
    sum_num = 0
    for t in num:
        sum_num = sum_num + t
        
    mean = sum_num / len(num)
    return mean
print("The average stop value for 80 is", mean([5,12,8,9,7,14,10,9]))
# Out:
# The average stop value for 80 is 9.25

# %%
a = numpy.loadtxt('samples/3.raw', skiprows=1, delimiter=',')
stop = 7
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 6400794.808129405
# 100

# %%
a = numpy.loadtxt('samples/4.raw', skiprows=1, delimiter=',')
stop = 15
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 2927377.1463102633
# 100

# %%
a = numpy.loadtxt('samples/5.raw', skiprows=1, delimiter=',')
stop = 14
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 3040498.023090506
# 100

# %%
a = numpy.loadtxt('samples/7.raw', skiprows=1, delimiter=',')
stop = 13
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 2395869.9119639513
# 100

# %%
a = numpy.loadtxt('samples/9.raw', skiprows=1, delimiter=',')
stop = 22
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 1993830.4678251168
# 100

# %%
a = numpy.loadtxt('samples/12.raw', skiprows=1, delimiter=',')
stop = 13
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 2332158.481210942
# 100

# %%
a = numpy.loadtxt('samples/13.raw', skiprows=1, delimiter=',')
stop = 14
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 1881908.559217747
# 100

# %%
a = numpy.loadtxt('samples/14.raw', skiprows=1, delimiter=',')
stop = 9
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 4539437.244639149
# 100

# %%
a = numpy.loadtxt('samples/15.raw', skiprows=1, delimiter=',')
stop = 9
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 4252674.440428065
# 100

# %%
#Stop= 7, 15, 14, 13, 22, 13, 14, 9, 9
print("The average stop value for 100 is", mean([7,15,14,13,22,13,14,9,9]))
# Out:
# The average stop value for 100 is 12.88888888888889

# %%
a = numpy.loadtxt('samples/2.raw', skiprows=1, delimiter=',')
stop = 14
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 4192817.8514862056
# 120

# %%
a = numpy.loadtxt('samples/8.raw', skiprows=1, delimiter=',')
stop = 13
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 4104099.560533794
# 120

# %%
a = numpy.loadtxt('samples/11.raw', skiprows=1, delimiter=',')
stop = 11
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 5480487.477292214
# 120

# %%
a = numpy.loadtxt('samples/18.raw', skiprows=1, delimiter=',')
stop = 17
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 2224954.39677121
# 120

# %%
#Stop= 14, 13, 11, 17
print("The average stop value for 120 is", mean([14,13,11,17]))
# Out:
# The average stop value for 120 is 13.75

# %%
#Observation:
    #Samples 0=20 do not give even sampling for each point set
    #Let len(num) = 10 for 80, 100, and 120

# %%
a = numpy.loadtxt('samples/21.raw', skiprows=1, delimiter=',')
stop = 5
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 7099197.580295765
# 80

# %%
a = numpy.loadtxt('samples/22.raw', skiprows=1, delimiter=',')
stop = 19
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 1982620.0875147737
# 120

# %%
a = numpy.loadtxt('samples/23.raw', skiprows=1, delimiter=',')
stop = 12
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 2977798.8443968524
# 100

# %%
a = numpy.loadtxt('samples/25.raw', skiprows=1, delimiter=',')
stop = 14
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 3081117.9171080245
# 120

# %%
a = numpy.loadtxt('samples/26.raw', skiprows=1, delimiter=',')
stop = 19
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 2551529.520792333
# 120

# %%
a = numpy.loadtxt('samples/27.raw', skiprows=1, delimiter=',')
stop = 15
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 3533543.7103653955
# 120

# %%
a = numpy.loadtxt('samples/28.raw', skiprows=1, delimiter=',')
stop = 16
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 1566228.3758151364
# 120

# %%
a = numpy.loadtxt('samples/29.raw', skiprows=1, delimiter=',')
stop = 14
x = a[:stop, 0]
y = a[:stop, 1]
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1, a_0))
plt.plot(a[:,0], a[:,1])
plt.plot(a[:stop,0], fit(a[:stop,0]));
len(a)
# Out:
# 2229829.043351289
# 80
